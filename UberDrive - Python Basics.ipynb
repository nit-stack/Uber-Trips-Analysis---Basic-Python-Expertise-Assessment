# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True) 
# %matplotlib inline

# %%
# Get the Data
uber_drives = pd.read_csv(r"C:\Users\nitis\Downloads\uberdrive.csv")
uber_drives
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Show the last 10 records of the dataset.

# %%
uber_drives[-10:]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1145  12/30/2016 10:15  12/30/2016 10:33  Business           Karachi
# 1146  12/30/2016 11:31  12/30/2016 11:56  Business           Karachi
# 1147  12/30/2016 15:41  12/30/2016 16:03  Business           Karachi
# 1148  12/30/2016 16:45  12/30/2016 17:08  Business           Karachi
# 1149  12/30/2016 23:06  12/30/2016 23:10  Business           Karachi
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 1145           Karachi     2.8  Errand/Supplies
# 1146           Karachi     2.9  Errand/Supplies
# 1147           Karachi     4.6  Errand/Supplies
# ...

# %% [markdown]
# ## Show the first 10 records of the dataset.

# %%
uber_drives[:10]
# Out:
#         START_DATE*         END_DATE* CATEGORY*           START*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# ...

# %% [markdown]
# ## Show the dimension(number of rows and columns) of the dataset.

# %%
uber_drives.shape
# Out:
# (1155, 7)

# %% [markdown]
# ## Show the size (Total number of elements) of the dataset.

# %%
uber_drives.size
# Out:
# 8085

# %% [markdown]
# ## Display the information about all the variables of the data set.

# %%
uber_drives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# ## Check for missing values.

# %%
uber_drives.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [1155 rows x 7 columns]

# %% [markdown]
# ## How many missing values are present?

# %%
uber_drives.isnull().sum().sum()
# Out:
# 502

# %% [markdown]
# ## Get the summary of the original data.

# %%
uber_drives.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %% [markdown]
# ## Drop the missing values and store data in a new dataframe.

# %%
df = uber_drives.dropna()
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# 5     01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Karachi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Karachi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# ## Check the information of the dataframe(df).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 653 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  653 non-null    object
#  1   END_DATE*    653 non-null    object
#  2   CATEGORY*    653 non-null    object
#  3   START*       653 non-null    object
#  4   STOP*        653 non-null    object
#  5   MILES*       653 non-null    float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 40.8+ KB

# %% [markdown]
# ## Get the unique start destinations.

# %%
df['START*'].unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Lake Wellingborough',
#        'Fayetteville Street', 'Raleigh', 'Whitebridge', 'Hazelwood',
#        'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill', 'Northwoods',
#        'Edgehill Farms', 'Eastgate', 'East Elmhurst', 'Long Island City',
#        'Katunayaka', 'Colombo', 'Nugegoda', 'Unknown Location',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Preston',
#        'Heritage Pines', 'Tanglewood', 'Waverly Place', 'Wayne Ridge',
#        'Westpark Place', 'East Austin', 'The Drag', 'South Congress',
#        'Georgian Acres', 'North Austin', 'West University', 'Austin',
# ...

# %% [markdown]
# ## What is the total number of unique start destinations?

# %%
uber_drives['START*'].nunique()
# Out:
# 176

# %% [markdown]
# ## What is the total number of unique stop destinations.

# %%
uber_drives['STOP*'].nunique()
# Out:
# 187

# %% [markdown]
# ## Display all the Uber trips that has the starting point of San Francisco.

# %%
uber_drives.loc[uber_drives['START*'] == 'San Francisco']
# Out:
#           START_DATE*         END_DATE* CATEGORY*         START*       STOP*  \
# 362  05-09-2016 14:39  05-09-2016 15:06  Business  San Francisco   Palo Alto
# 440   6/14/2016 16:09   6/14/2016 16:39  Business  San Francisco  Emeryville
# 836  10/19/2016 14:02  10/19/2016 14:31  Business  San Francisco    Berkeley
# 917  11-07-2016 19:17  11-07-2016 19:57  Business  San Francisco    Berkeley
# 919  11-08-2016 12:16  11-08-2016 12:49  Business  San Francisco    Berkeley
# 927  11-09-2016 18:40  11-09-2016 19:17  Business  San Francisco     Oakland
# 933  11-10-2016 15:17  11-10-2016 15:22  Business  San Francisco     Oakland
# 966  11/15/2016 20:44  11/15/2016 21:00  Business  San Francisco    Berkeley
#
#      MILES*         PURPOSE*
# 362    20.5  Between Offices
# 440    11.6          Meeting
# 836    10.8              NaN
# 917    13.2  Between Offices
# 919    11.3          Meeting
# 927    12.7   Customer Visit
# 933     9.9   Temporary Site
# 966    11.8   Temporary Site

# %% [markdown]
# ## What is the most popular starting point for the Uber drivers?

# %%
uber_drives['START*'].value_counts()
# Out:
# Cary                     201
# Unknown Location         148
# Morrisville               85
# Whitebridge               68
# Islamabad                 57
#                         ...
# Soho                       1
# Connecticut Avenue         1
# Midtown East               1
# Latta                      1
# Congress Ave District      1
# Name: START*, Length: 176, dtype: int64

# %% [markdown]
# ## What is the most popular dropping point for the Uber drivers?

# %%
uber_drives['STOP*'].value_counts()
# Out:
# Cary                    203
# Unknown Location        149
# Morrisville              84
# Whitebridge              65
# Islamabad                58
#                        ...
# Farmington Woods          1
# Bay Farm Island           1
# North Berkeley Hills      1
# Mebane                    1
# Harden Place              1
# Name: STOP*, Length: 187, dtype: int64

# %% [markdown]
# ## List the most frequent route taken by Uber drivers.

# %%
df = uber_drives.dropna()
df = pd.DataFrame(df.groupby(['START*', 'STOP*']).size())
df = df.rename(columns = {0:'Count'})
df = df.sort_values(['Count'], ascending = False)
df.loc[df['Count'] == max(df['Count'])]
# Out:
#                     Count
# START* STOP*
# Cary   Morrisville     52

# %% [markdown]
# ## Display all types of purposes for the trip in an array.

# %%
df[['PURPOSE*']].to_numpy()
# Out:
# array([['Meal/Entertain'],
#        ['Errand/Supplies'],
#        ['Meeting'],
#        ['Customer Visit'],
#        ['Meal/Entertain'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Customer Visit'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Temporary Site'],
#        ['Errand/Supplies'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Errand/Supplies'],
#        ['Customer Visit'],
#        ['Errand/Supplies'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Customer Visit'],
#        ['Errand/Supplies'],
#        ['Errand/Supplies'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Meal/Entertain'],
#        ['Temporary Site'],
#        ['Meeting'],
#        ['Meeting'],
#        ['Customer Visit'],
#        ['Errand/Supplies'],
#        ['Meal/Entertain'],
# ...

# %% [markdown]
# ## Plot a bar graph of Purpose vs Miles(Distance).

# %%
df = pd.DataFrame(uber_drives['MILES*'].groupby(uber_drives['PURPOSE*']).sum())
df = df.reset_index()
sns.barplot(x = df['MILES*'], y = df['PURPOSE*'])
# Out:
# <AxesSubplot:xlabel='MILES*', ylabel='PURPOSE*'>

# %% [markdown]
# ## Display a dataframe of Purpose and the distance travelled for that particular Purpose.

# %%
df = pd.DataFrame(uber_drives['MILES*'].groupby(uber_drives['PURPOSE*']).sum())
df
# Out:
#                  MILES*
# PURPOSE*
# Airport/Travel     16.5
# Between Offices   197.0
# Charity ($)        15.1
# Commute           180.2
# Customer Visit   2089.5
# Errand/Supplies   508.0
# Meal/Entertain    911.7
# Meeting          2851.3
# Moving             18.2
# Temporary Site    523.7

# %% [markdown]
# ## Plot number of trips vs Category of trips.

# %%
 sns.countplot(uber_drives['CATEGORY*']);
# Out:
# C:\Users\nitis\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## What is proportion of miles that are covered as Business trips and what is the proportion of miles that are covered as Personal trips?

# %%
a = uber_drives['MILES*'].sum()
print(a)
b =  uber_drives[uber_drives['CATEGORY*'] == 'Business'].sum()
print(b)
c = uber_drives[uber_drives['CATEGORY*'] == 'Personal'].sum()
print(c)
# Out:
# 12204.7
# START_DATE*    01-01-2016 21:1101-02-2016 01:2501-02-2016 20:...
# END_DATE*      01-01-2016 21:1701-02-2016 01:3701-02-2016 20:...
# CATEGORY*      BusinessBusinessBusinessBusinessBusinessBusine...
# START*         Fort PierceFort PierceFort PierceFort PierceFo...
# STOP*          Fort PierceFort PierceFort PierceFort PierceWe...
# MILES*                                                   11487.0
# dtype: object
# START_DATE*    02-09-2016 10:5402-09-2016 11:4302-09-2016 13:...
# END_DATE*      02-09-2016 11:0702-09-2016 11:5002-09-2016 13:...
# CATEGORY*      PersonalPersonalPersonalPersonalPersonalPerson...
# START*         WhitebridgeNorthwoodsTanglewoodPrestonEast Elm...
# STOP*          NorthwoodsTanglewoodPrestonWhitebridgeJackson ...
# MILES*                                                     717.7
# dtype: object

# %%
## Taking a random variable x as Total Miles
## Taking a random variable y as Total Miles clocked as Business Trips
## Taking a random variable z as Total Miles clocked as Personal Trips

x = 12204.7
y = 11487
z = 717.7

## Taking a random variable m as Proportion of miles covered as business trips
## Taking a random variable n as Proportion of miles covered as personal trips

m = y/x
print(m)
n = z/x
print(n)
# Out:
# 0.9411947856153776
# 0.058805214384622315
